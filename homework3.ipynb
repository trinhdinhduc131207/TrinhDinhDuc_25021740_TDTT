# %% [markdown]
# # [

# %%
#bai14
A = []
while True:
    try:
        n = int(input('nhap day so nguyen:'))
        if n == -1:
            break
        A.append(n)
    except ValueError:
        print('ban nhap sai kieu so roi moi ban nhap lai')
        continue
max_so = A[0]
min_so = A[0]
for i in range (1,len(A)):
    if max_so < A[i]:
        max_so = A[i]
    if min_so > A[i]:
        min_so = A[i]
print('so lon nhat la:', max_so)
print('so nho nhat la:', min_so)
# Out:
# nhap day so nguyen: 3
# nhap day so nguyen: 4
# nhap day so nguyen: 56
# nhap day so nguyen: 78
# nhap day so nguyen: 123
# nhap day so nguyen: 54
# nhap day so nguyen: 2
# nhap day so nguyen: 8
# nhap day so nguyen: 9
# nhap day so nguyen: -1
# so lon nhat la: 123
# so nho nhat la: 2

# %%
#bai15
try:
    a = 0
    n = int(input('nhap vao so nguyen:'))
    while n > 0:
        n = n//10
        a = a + 1
    print('so da nhap co', a, 'chu so')
except ValueError:
    print('ban nhap sai roi')
# Out:
# nhap vao so nguyen: 123
# so da nhap co 3 chu so

# %%
#bai16
try:
    n = int(input('nhap so nguyen:'))
    while n
