# %%
try:







    
except ValueError:
 print ('ban khong nhap so ngyen')

# %%
if 
break ngat ngay dong lenh do
continue chi trong vog lap for
Sum la lenh gi trong phan gan bien 
so nguyen to la so chia het cho 1 va chinh no

# %%
#tim xem co phai la so nguyen duong hay khong
import math 
n = int(input('nhap so nguyen duong:'))
if n < 2:
    print ('khong phai la so nguyen to')
else :
  for i in range (2, int(math.sqrt(n))+1):
      if n%i==0 :
          print('khong phhai la so nguyen to')
          break
  else:
          print('la so nguyen to')
# Out:
# nhap so nguyen duong: 7
# la so nguyen to

# %%
#tinh giai thua cua mot so nguyen duong cho truoc
try:
    
    A = 1
    n = int(input('nhap so nguyen duong:'))
    if n<0 :            
         print('ban nhap sai roi')
    else:       
         for i in range (1, n + 1):
              A *= i
         print ('giai thua cua so nguyen da cho la:', A)
except ValueError :
   print('so ban nhap khong phai so nguyen roi')
# Out:
# nhap so nguyen duong: 4.5
# so ban nhap khong phai so nguyen roi

# %%
25021693 Nguyễn Đức Duy
11:11 AM
#w4a4
try:   
    n = int(input("Nhap so n:"))
    count = 0
    temp = n
    for _ in range (100):
        if temp > 0:
            count += 1
            temp //= 10
        else:
            break
    if n == 0:
        count = 1
    print("So chu so la:", count)
except ValueError:
    print("Loi: Ban phai nhap so nguyen!")

# %%
#nhap mot so nguyen n am hoac duong 
#tinh tong so chan cua cac so trong chu so 
#vi du 123456 = 12
n = int(input('nhap vao so nguyen am hoac duong:'))
n = abs(n) #loai bo dau cua n neu n la so am se chuyen thanh so duong
Sum = 0
temp = n
for _ in range (10000):
    if temp>0 :
        d = temp%10
        if d%2 == 0:
            Sum += d
        temp //= 10
    else:
        break
print (Sum)
# Out:
# nhap vao so nguyen am hoac duong: 123456
# 12

# %%
Phan Thùy Dương
11:59 AM
n = int(input())
flag =  False
for _ in range(n):
    x = int(input())
    if x == 42:
        flag =  True
        break
if flag == True:
    print(" I've found the meaning of life ")
else:
    print(" It's a joke")
# Out:
#   Cell In[38], line 2
#     11:59 AM
#          ^
# SyntaxError: invalid non-printable character U+202F

# %%
n = int(input())
flag = False
for _ in range(n):
     x = int(input())
     if x == 42:
         flag = True
         break
if flag = True:
         print('2')
# Out:
#  3
#  1
# 2
#  2
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 n = int(input())
#       2 for _ in range(n):
# ----> 3      x = int(input())
#       4      if x == 42:
#       5          print('1')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
try:
  n = int(input('nhap so nguyen duong:'))
  tong = 0
  if n<0 or n>=10**6:
      print('ban nhap khong trong khoang cho phep roi')
  else:
     for i in range (2,n + 1,2):
        if n%i == 0:
            tong += 1
     print (tong)
except ValueError:
    print('ban chua nhap so nguyen roi')
# Out:
# nhap so nguyen duong: -2
# 0

# %%
n = int(input('nhap so thang tinh de tinh lai:'))
X = int(input('nhap so tien ban dau gui:'))
tien = 0
for i in range (n):
    tien = X*0.007
    X += tien_rut
print(int(X))
# Out:
# nhap so thang tinh de tinh lai: 3
# nhap so tien ban dau gui: 1000000
# 1021444

# %%
a = int(input())
b = int(input())
x = 0 
y = 0
for i in range (1,a):
     if a%i == 0: 
         x += i
for c in range (1,b):
     if b%c == 0:
         y += c
if x == b and y == a:
    print('True')
else:
    print('False')
# Out:
#  284
#  220
# True

# %%
#W4A1
try:
    tong = 0
    n = int(input('nhap so nguyen duong:'))
    for i in range (1,n + 1):
        tong += i
    print('tong la:', tong)
except ValueError:
    print('ban nhap sai roi, phai nhap so nguyen')
# Out:
# nhap so nguyen duong: 4.5
# ban nhap sai roi, phai nhap so nguyen

# %%
#W4A2
try:
    n = int(input('nhap so nguyen:'))
    if n < 2:
        print('khong phai la so nguyen to')
    else:
        for i in range (2,n):
            if n%i == 0:
                print('khong phai la so nguyen to')
                break
        else:
                print('la so nguyen to')
except ValueError:
    print('day khong phai la so nguyen moi ban nhap lai')
# Out:
# nhap so nguyen: 3.5
# day khong phai la so nguyen moi ban nhap lai

# %%
#W4A3
giai_thua = 1
n = int(input('nhap so nguyen:'))
if n>0 and n<100:
    for i in range (1,n+1):
        giai_thua *= i
    print ('giai thua cua so tren la:', giai_thua)
# Out:
# nhap so nguyen: 3
# giai thua cua so tren la: 6

# %%
#W4A4
n = int(input('nhap so nguyen am hoac duong:'))
n = abs(n) #loai bo dau cua so am
print (n)

# %%
#W4A5
try:
    n = int(input('nhap so nguyen n:'))
    for i in range (n):
        x = int(input('nhap so nguyen:'))
        if x == 42:
            print("I've found the meaning of life!")
            break
    else:
        print("it's a joke")
except ValueError:
    print ('so ban nhap khong phai so nguyen moi nhap lai')
# Out:
# nhap so nguyen: 4
# nhap so nguyen: 23
# nhap so nguyen: 3
# nhap so nguyen: 5
# nhap so nguyen: 7
# it's a joke

# %%
#W4A6
try:
    tong = 0
    a = int(input('nhap so nguyen duong:'))
    b = int(input('nhap so nguyen duong:'))
    if a <= b:
        for i in range (a,b+1):
            for j in range (2,i):
                if i%j == 0:
                    break
            else:
                tong += i 
        print(tong)
    else:
        pritn('phải nhập số b lớn hơn số a')
except ValueError:
    print ('nhap khong phai so nguyen')
# Out:
# nhap so nguyen duong: 2
# nhap so nguyen duong: 7
# 17

# %%
#7
import math
A = []
n = float(input('nhap so nguyen duong:'))
for i in range (1, sqrt(n)+1):
    if n%i==0:
        for j in range (2,i):
            if i%j==0:
                break
        else:
            A.append(i)
print(A[len(A)-1])
# Out:
# nhap so nguyen duong: 123456789
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 A = []
#       4 n = float(input('nhap so nguyen duong:'))
# ----> 5 for i in range (1, sqrt(n)+1):
#       6     if n%i==0:
#       7         for j in range (2,i):
#
# NameError: name 'sqrt' is not defined

# %%
#W4A8
n = int(input('nhap so nguyen duong:'))
so_buoc = 0

for i in range (100):
    s = str(n)
    if s == (s[::-1]):# để đảo số từ cuối lên đầu check xem có phải là số palindrome ko
        print('so buoc thuc hien la:', so_buoc)
        print('so palindrome la:', n)
        break
    else:
        reverse = int(s[::-1])
        n = n + reverse
        so_buoc += 1
else:
    print('khong tim thay palindrome sau 100 buoc')
# Out:
# nhap so nguyen duong: 860508
# khong tim thay palindrome sau 100 buoc

# %%
#W4A9
import math 
S = []
n = int(input('nhap so nguyen duong:'))
if n >=1:
    for i in range (1, n+1):
if math.sqrt(i)%int(math.sqrt(i)) == 0:
            str(S)
            if len(set(S)) == len(S): #set()loai bo phan tu bi trung nhau trong danh sach
                    print(i, end=" ") #end=" " in ra moi so cach nhau bang dau gi do or cach
else:
    print('no number')
# Out:
# nhap so nguyen duong: 100
# 1 4 9 16 25 36 49 64 81 100

# %%
#W4A10
n = int(input("Nhập số nguyên dương n: "))

max_length = 0
best_x = 1

for x in range(1, n + 1):
    k = x
    count = 1    
    for _ in range(10000):
        if k == 1:
            break # neu thoa man dieu kien thi dung lai
        if k % 2 == 0:#neu chu thoa man k == 1 thi chay den cai nay
            k = k // 2
        else:
            k = 3 * k + 1
        count += 1 #moi lan tinh cong them mot buoc                        

    if count > max_length: #chua hieu lam 
        max_length = count
        best_x = x
    elif count == max_length and x < best_x: # chua hieu lam 
        best_x = x

print(best_x, max_length)
# Out:
# Nhập số nguyên dương n:  100
# 97 119

# %%
#W4A11
try:
  n = int(input('nhap so nguyen duong:'))
  tong = 0
  if n<0 or n>=10**6:
      print('ban nhap khong trong khoang cho phep roi')
  else:
     for i in range (2,n + 1,2):
        if n%i == 0:
            tong += 1
     print (tong)
except ValueError:
    print('ban chua nhap so nguyen roi')
# Out:
# nhap so nguyen duong: 16
# 4

# %%
#W4A12 chua hoan thanh
X = int(input('nhap vao so tien gui:'))
N = int(input('nhap so thang tinh lai:'))
for i in range (N):
    X = X*1.007
print(int(X))
# Out:
# nhap vao so tien gui: 100000
# nhap so thang tinh lai: 3
# 102114

# %%
#W4A13
a = int(input('nhap so nguyen:'))
b = int(input('nhap so nguyen;'))
for i in range (1,a):
    A = 0
    if a%i == 0:
        A += a
for i in range (1,b):
    B = 0
    if b%i == 0:
        B += b
if A == B:
    print('True')
else:
    print('False')
# Out:
# nhap so nguyen: 220
# nhap so nguyen; 284
# True

# %%
#W4A14
m = int(input('nhap so nguyen duong:'))
n = int(input('nhap so nguyen:'))
A = []
if m>n:
    for i in range (1,n + 1):
        if m%i == 0:
            A.insert(0,i)
    print(A[0])
elif m<n:
    for i in range (1,m + 1):
        if n%i == 0:
            A.insert(0,i)
    print(A[0])
else:
    print(m)
# Out:
# nhap so nguyen duong: 7
# nhap so nguyen: 3
# 1

# %%
#W4A15
m = int(input('tong so con la:'))
n = int(input('tong so chan ga va cho la:'))
for ga in range (1,m + 1):
    cho = m - ga
    if 2*ga + 4*cho == n:
        print('so luong ga la:', ga)
        print('so luong cho la:', cho)
        break
else:
    print('invalid')
# Out:
# tong so con la: 35
# tong so chan ga va cho la: 99
# invalid

# %%
#W4A8
n = int(input('nhap vao so nguyen duong
